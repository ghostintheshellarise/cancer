# %% [markdown]
# # Cholangiocarcinoma

# %% [markdown]
# ## 1. What genetic aberrations found in Cholangiocarcinoma?

# %% [markdown]
# According to the entry at KEGG database, Cholangiocarcinoma has several documented genetic mutations.  In below I extract those genes from said entry (https://www.kegg.jp/entry/H00046)

# %%
import KEGGparser as kp # customised functions to extract data from KEGG when default parser is not available.
import pubmedExtractor as pme # customized functions using Biopython to extract PubMed abstracts.
import pandas as pd
import networkx as nx
import time

# %%
genes = kp.get_disease_genes('H00046')

# %%
# documented genetic mutations related to Cholangiocarcinoma
for entry in genes:
    print (entry)
# Out:
# ['K-ras', 'mutation', '[HSA:3845]', '[KO:K07827]']
# ['p53', 'mutation', '[HSA:7157]', '[KO:K04451]']
# ['c-Met', 'overexpression', '[HSA:4233]', '[KO:K05099]']
# ['ERBB2', 'overexpression,amplification', '[HSA:2064]', '[KO:K05083]']
# ['p16/INK4A', 'mutation', '[HSA:1029]', '[KO:K06621]']
# ['COX2', 'overexpression', '[HSA:5743]', '[KO:K11987]']

# %%
def get_gene_network(geneids):
    """
    Cutomized parser to extract said information from KEGG
    Input: an URL of said Gene
    Output: networkIds in format of 'Nxxxxxx' that captures the signaling pathway containing the said gene
    """
    networkIds = []
    url = r'https://www.kegg.jp/entry/hsa:'+geneids
    tables = pd.read_html(url) # Returns list of all tables on page
    length = len(tables)
    for i in range(0,length,1):
        if type(tables[i][0][0])==str:
            if tables[i][0][0].startswith('N') and tables[i][0][0][-1].isnumeric():
                networkIds.append(tables[i][0][0])
    return networkIds

# %%
# %%time
collection = []
for entry in genes:
    ids = entry[2].replace('[','').replace(']','').replace('HSA:','')
    networks = get_gene_network(ids)
    for n in networks:
        #variant = kp.get_network_variant(n)
        collection.append([entry[0], entry[1], n])
# Out:
# CPU times: user 730 ms, sys: 18 ms, total: 748 ms
# Wall time: 4.69 s

# %%
# the collection of genes and their related networks
collection
# Out:
# [['K-ras', 'mutation', 'N00001'],
#  ['K-ras', 'mutation', 'N00002'],
#  ['K-ras', 'mutation', 'N00003'],
#  ['K-ras', 'mutation', 'N00004'],
#  ['K-ras', 'mutation', 'N00005'],
#  ['K-ras', 'mutation', 'N00006'],
#  ['K-ras', 'mutation', 'N00007'],
#  ['K-ras', 'mutation', 'N00008'],
#  ['K-ras', 'mutation', 'N00009'],
#  ['K-ras', 'mutation', 'N00011'],
#  ['K-ras', 'mutation', 'N00012'],
#  ['K-ras', 'mutation', 'N00014'],
#  ['K-ras', 'mutation', 'N00015'],
#  ['K-ras', 'mutation', 'N00016'],
#  ['K-ras', 'mutation', 'N00018'],
#  ['K-ras', 'mutation', 'N00019'],
#  ['K-ras', 'mutation', 'N00020'],
#  ['K-ras', 'mutation', 'N00021'],
#  ['K-ras', 'mutation', 'N00022'],
#  ['K-ras', 'mutation', 'N00030'],
#  ['K-ras', 'mutation', 'N00031'],
#  ['K-ras', 'mutation', 'N00032'],
#  ['K-ras', 'mutation', 'N00041'],
#  ['K-ras', 'mutation', 'N00096'],
#  ['K-ras', 'mutation', 'N00097'],
#  ['K-ras', 'mutation', 'N00103'],
#  ['K-ras', 'mutation', 'N00104'],
#  ['K-ras', 'mutation', 'N00152'],
#  ['K-ras', 'mutation', 'N00157'],
#  ['K-ras', 'mutation', 'N00160'],
#  ['K-ras', 'mutation', 'N00215'],
#  ['K-ras', 'mutation', 'N00216'],
#  ['K-ras', 'mutation', 'N00217'],
#  ['K-ras', 'mutation', 'N00218'],
#  ['K-ras', 'mutation', 'N00229'],
#  ['K-ras', 'mutation', 'N00230'],
#  ['K-ras', 'mutation', 'N00233'],
#  ['K-ras', 'mutation', 'N00235'],
#  ['K-ras', 'mutation', 'N00237'],
#  ['K-ras', 'mutation', 'N00246'],
#  ['K-ras', 'mutation', 'N00248'],
#  ['K-ras', 'mutation', 'N00252'],
#  ['K-ras', 'mutation', 'N00259'],
#  ['K-ras', 'mutation', 'N00276'],
#  ['K-ras', 'mutation', 'N00277'],
#  ['K-ras', 'mutation', 'N00278'],
#  ['K-ras', 'mutation', 'N00279'],
#  ['K-ras', 'mutation', 'N00280'],
#  ['K-ras', 'mutation', 'N00367'],
#  ['K-ras', 'mutation', 'N00369'],
#  ['K-ras', 'mutation', 'N00386'],
#  ['K-ras', 'mutation', 'N00392'],
#  ['K-ras', 'mutation', 'N00513'],
#  ['K-ras', 'mutation', 'N00538'],
#  ['K-ras', 'mutation', 'N00539'],
#  ['K-ras', 'mutation', 'N00540'],
#  ['K-ras', 'mutation', 'N00541'],
#  ['K-ras', 'mutation', 'N00542'],
#  ['K-ras', 'mutation', 'N00876'],
#  ['K-ras', 'mutation', 'N00877'],
#  ['K-ras', 'mutation', 'N00878'],
#  ['K-ras', 'mutation', 'N00913'],
#  ['K-ras', 'mutation', 'N00914'],
#  ['K-ras', 'mutation', 'N00994'],
#  ['K-ras', 'mutation', 'N00996'],
#  ['K-ras', 'mutation', 'N01062'],
#  ['K-ras', 'mutation', 'N01064'],
#  ['K-ras', 'mutation', 'N01343'],
#  ['K-ras', 'mutation', 'N01344'],
#  ['K-ras', 'mutation', 'N01351'],
#  ['K-ras', 'mutation', 'N01352'],
#  ['K-ras', 'mutation', 'N01353'],
#  ['K-ras', 'mutation', 'N01354'],
#  ['K-ras', 'mutation', 'N01360'],
#  ['K-ras', 'mutation', 'N01361'],
#  ['K-ras', 'mutation', 'N01408'],
#  ['K-ras', 'mutation', 'N10027'],
#  ['p53', 'mutation', 'N00066'],
#  ['p53', 'mutation', 'N00067'],
#  ['p53', 'mutation', 'N00068'],
#  ['p53', 'mutation', 'N00076'],
#  ['p53', 'mutation', 'N00115'],
#  ['p53', 'mutation', 'N00131'],
#  ['p53', 'mutation', 'N00167'],
#  ['p53', 'mutation', 'N00169'],
#  ['p53', 'mutation', 'N00223'],
#  ['p53', 'mutation', 'N00263'],
#  ['p53', 'mutation', 'N00347'],
#  ['p53', 'mutation', 'N00358'],
#  ['p53', 'mutation', 'N00420'],
#  ['p53', 'mutation', 'N00481'],
#  ['p53', 'mutation', 'N00497'],
#  ['p53', 'mutation', 'N00499'],
#  ['p53', 'mutation', 'N00520'],
#  ['p53', 'mutation', 'N00521'],
#  ['p53', 'mutation', 'N00522'],
#  ['p53', 'mutation', 'N00535'],
#  ['p53', 'mutation', 'N00536'],
#  ['p53', 'mutation', 'N00592'],
#  ['p53', 'mutation', 'N00697'],
#  ['p53', 'mutation', 'N00982'],
#  ['p53', 'mutation', 'N01058'],
#  ['c-Met', 'overexpression', 'N00005'],
#  ['c-Met', 'overexpression', 'N00043'],
#  ['c-Met', 'overexpression', 'N00044'],
#  ['c-Met', 'overexpression', 'N00143'],
#  ['c-Met', 'overexpression', 'N00216'],
#  ['c-Met', 'overexpression', 'N00246'],
#  ['c-Met', 'overexpression', 'N00247'],
#  ['c-Met', 'overexpression', 'N00248'],
#  ['c-Met', 'overexpression', 'N00249'],
#  ['c-Met', 'overexpression', 'N00259'],
#  ['c-Met', 'overexpression', 'N00260'],
#  ['c-Met', 'overexpression', 'N01062'],
#  ['c-Met', 'overexpression', 'N01063'],
#  ['c-Met', 'overexpression', 'N10024'],
#  ['ERBB2', 'overexpression,amplification', 'N00021'],
#  ['ERBB2', 'overexpression,amplification', 'N00022'],
#  ['ERBB2', 'overexpression,amplification', 'N00034'],
#  ['ERBB2', 'overexpression,amplification', 'N00087'],
#  ['ERBB2', 'overexpression,amplification', 'N00095'],
#  ['ERBB2', 'overexpression,amplification', 'N00252'],
#  ['ERBB2', 'overexpression,amplification', 'N00253'],
#  ['ERBB2', 'overexpression,amplification', 'N10009'],
#  ['p16/INK4A', 'mutation', 'N00066'],
#  ['p16/INK4A', 'mutation', 'N00067'],
#  ['p16/INK4A', 'mutation', 'N00069'],
#  ['p16/INK4A', 'mutation', 'N00070'],
#  ['p16/INK4A', 'mutation', 'N00071'],
#  ['p16/INK4A', 'mutation', 'N00076'],
#  ['p16/INK4A', 'mutation', 'N00494'],
#  ['p16/INK4A', 'mutation', 'N00536'],
#  ['COX2', 'overexpression', 'N00317'],
#  ['COX2', 'overexpression', 'N00402']]

# %%
# %%time
interim = []
for entry in collection:
    networkName = kp.get_network_name(entry[2])
    definition = kp.get_network_definition(entry[2])
    variant = kp.get_network_variant(entry[2])
    interim.append([entry[0], entry[1], entry[2], networkName, definition[0], definition[1], variant])
# Out:
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00002                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00002                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00002                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00003                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00003                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00003                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00004                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00004                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00004                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00005                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00005                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00005                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00006                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00006                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00006                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00007                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00007                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00007                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00008                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00008                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00008                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00009                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00009                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00009                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00011                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00011                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00011                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00012                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00012                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00012                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00014                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00014                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00014                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00016                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00016                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00016                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00018                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00018                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00018                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00020                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00020                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00020                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00022                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00022                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00022                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00030                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00030                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00030                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00031                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00031                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00031                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00031                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00031                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00031                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00032                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00032                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00032                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00032                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00032                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00032                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00041                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00041                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00041                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00097                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00097                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00097                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00104                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00104                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00104                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00157                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00157                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00157                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00160                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00160                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00160                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00218                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00218                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00218                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00230                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00230                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00230                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00235                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00235                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00235                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00237                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00237                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00237                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00246                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00246                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00246                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00248                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00248                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00248                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00252                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00252                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00252                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00259                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00259                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00259                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00276                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00276                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00276                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00278                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00278                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00278                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00280                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00280                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00280                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00367                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00367                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00367                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00369                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00369                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00369                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00386                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00386                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00386                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00392                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00392                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00392                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00513                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00513                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00513                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00538                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00538                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00538                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00539                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00539                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00539                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00539                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00539                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00539                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00540                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00540                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00540                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00541                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00541                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00541                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00876                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00876                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00876                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00877                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00877                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00877                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00878                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00878                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00878                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00913                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00913                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00913                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00914                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00914                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00914                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00994                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00994                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00994                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00996                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00996                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00996                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00996                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00996                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00996                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01062                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01062                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01062                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01064                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01064                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01064                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01343                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01343                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01343                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01344                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01344                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01344                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01344                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01344                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01344                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01351                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01351                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01351                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01352                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01352                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01352                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01353                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01353                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01353                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01354                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01354                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01354                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01360                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01360                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01360                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01361                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01361                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01361                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01408                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01408                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01408                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01408                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
# ...
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01063                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01063                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01063                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01063                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01063                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N01063                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10024                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10024                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10024                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10024                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10024                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10024                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00022                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00022                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00022                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00034                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00034                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00034                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00034                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00034                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00034                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00087                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00087                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00087                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00095                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00095                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00095                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00252                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00252                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00252                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00253                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00253                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00253                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00253                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00253                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00253                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10009                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10009                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10009                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10009                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10009                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N10009                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00067                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00067                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00067                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00070                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00070                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00070                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00071                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00071                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00071                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00076                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00076                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword VARIANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00076                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00494                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00494                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00494                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00317                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00317                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00317                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00402                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00402                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00402                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00402                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword PERTURBANT, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00402                      Network) into github.com/bioservices. Thanks T.C.
# WARNING [bioservices:keggparser:119]:  Found keyword METABOLITE, which has not special
#     parsing for now. please report this issue with the KEGG
#     identifier (N00402                      Network) into github.com/bioservices. Thanks T.C.
# CPU times: user 5.03 s, sys: 1.07 s, total: 6.11 s
# Wall time: 1min 42s

# %%
# Normal pathway
for entry in interim:
    if entry[6][0]=='null':
        print (entry[0], entry[2], entry[4])
# Out:
# K-ras N00001 EGF -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> CCND1
# K-ras N00015 PDGF -> PDGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00019 FGF -> FGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00021 EGF -> (ERBB2+EGFR) -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00030 EGF -> EGFR -> GRB2 -> SOS -> RAS -> PI3K -> PIP3 -> AKT -| BAD
# K-ras N00096 EGF -> EGFR -> GRB2 -> SOS -> RAS -> (RASSF1+RASSF5) -> STK4
# K-ras N00103 EGF -> EGFR -> GRB2 -> SOS -> RAS -> RALGDS -> RAL
# K-ras N00152 CXCL8 -> CXCR2 -> GNB/G -> RAS -> RAF1 -> MEK -> ERK
# K-ras N00157 vGPCR -> GNB/G -> RAS -> RAF1 -> MEK -> ERK -> (HIF1A,FOS,JUN) => (VEGFA,PDGFB,ANGPT2)
# K-ras N00160 K1 -> RAS -> RAF -> MEK -> ERK
# K-ras N00215 KITLG -> KIT -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00216 HGF -> MET -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00217 FLT3LG -> FLT3 -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00218 FLT3LG -> FLT3 -> GRB2 -> SOS -> RAS -> PI3K -> PIP3 -> AKT -> MTOR
# K-ras N00229 TGFA -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00233 IGF -> IGF1R -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00277 EREG -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00279 AREG -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00367 E5 -| V-ATPase -| EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00369 E5 -> PDGFRB -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00386 UL55 -> PDGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00392 UL55 -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> (ELK1,SP1)
# K-ras N00538 Ca2+ -> PTK2B -> SRC -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00539 X -> VDAC3 -> Ca2+ -> PTK2B -> SRC -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00540 X -> SRC -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> ELK1
# K-ras N00541 X -> RAS -> RAF1 -> MEK -> ERK
# K-ras N00542 EGF -> EGFR -> GRB2 -> SOS -> RAS -> MEKK1 -> MKK4 -> JNK
# K-ras N00994 AGE -> AGER -> RAS -> RAF -> MEK -> ERK -> NFKB => (TNF,IL6,NOS2)
# K-ras N01343 ACh -> CHRNA7 -> Ca2+ -> RAS -> RAF -> MEK -> ERK -> CREB
# K-ras N01344 (NNK,NNN) -> CHRN -> Ca2+ -> RAS -> RAF -> MEK -> ERK -> (FOS,JUN,MYC,BCL2)
# K-ras N01351 E2 -> ESR1/2 -> SRC -> RAS -> RAF -> MEK -> ERK -> CREB
# K-ras N01352 BPA -> ESR1/2 -> SRC -> RAS -> RAF -> MEK -> ERK
# K-ras N01353 E2 -> ESR1/2 -> SRC -> RAS -> RAF -> MEK -> ERK -> (ESR1/2,AP1) => CHRNA9
# K-ras N01354 BPA -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N01360 P4 -> (PGR+SRC) -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> CCND1
# K-ras N01361 (P4,MPA) -> (PGR+SRC) -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> CCND1
# K-ras N01408 Metals -> ROS -> RAS -> RAF -> MEK -> ERK -> AP1
# p53 N00066 CDKN2A -| MDM2 -| TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F
# p53 N00167 (vIRF1,vIRF3) -| TP53
# p53 N00169 LANA -| TP53
# p53 N00223 EBNA1 -| USP7 -> TP53 => (CDKN1A,GADD45,BAX,BAK1,DDB2,POLK)
# p53 N00263 EBNA3C -> MDM2 -| TP53 => (CDKN1A,GADD45,BAX,BAK1,DDB2,POLK)
# p53 N00347 (ATM,ATR) -> TADA3 -> EP300 -> TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F
# p53 N00358 (E6+UBE3A) -| TP53
# p53 N00420 IE2-86 -| TP53
# p53 N00481 BZLF1 -| TP53 => (CDKN1A,GADD45,BAX,BAK1,DDB2,POLK)
# p53 N00497 TAX -| TP53 => CDKN1A -| (CDK2+CCNE) -> RB1 // E2F
# p53 N00499 (ATM,ATR) -> CHEK1 -> TP53 => CDKN1A -| (CDK1+CCNB)
# p53 N00520 NS5A -| TP53
# p53 N00521 Core -| TP53
# p53 N00522 NS3 -| TP53
# p53 N00535 X -| TP53 => (CDKN1A,BAX,FAS)
# p53 N00536 CDKN2A -| MDM2 -| TP53 => CDKN1A -| (CCNE+CDK2) -> RB1 // E2F
# p53 N00592 ICP0 -| TP53
# p53 N00697 P -> RCHY1 -| TP53
# c-Met N00043 HGF -> MET -> GAB1 -> PI3K -> PIP3 -> AKT -| BAD
# c-Met N00216 HGF -> MET -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# ERBB2 N00021 EGF -> (ERBB2+EGFR) -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# p16/INK4A N00066 CDKN2A -| MDM2 -| TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F
# p16/INK4A N00069 CDKN2A -| (CCND+CDK4/6) -> RB1 // E2F
# p16/INK4A N00494 TAX -| CDKN2A
# p16/INK4A N00536 CDKN2A -| MDM2 -| TP53 => CDKN1A -| (CCNE+CDK2) -> RB1 // E2F
# COX2 N00317 KA -> (AHR+ARNT) => (IL6,IL22,PTGS2,VEGFA,CYP1A1,CYP1B1)
# COX2 N00402 US28 -> GNAQ -> PLCB -> IP3 -> Ca2+ -> CALM -- CN -> NFAT => (CXCL8,PTGS2)

# %%
# Deviant pathways. The aberrant gene is indicated with an asterisk.
# Drug/target is also indicated.
for entry in interim:
    if entry[6][0]!='null':
        print (entry[0], entry[2], entry[4])
# Out:
# K-ras N00002 BCR-ABL -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00003 KIT* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00004 FLT3* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00005 MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> CCND1
# K-ras N00006 EGFR* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00007 EML4-ALK -> RAS -> RAF -> MEK -> ERK -> CCND1
# K-ras N00008 RET* -> RAS -> RAF -> MEK -> ERK
# K-ras N00009 TRK* -> RAS -> RAF -> MEK -> ERK
# K-ras N00011 FGFR3* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> MSK1 -> MYC
# K-ras N00012 (KRAS*,NRAS*) -> RAF -> MEK -> ERK -> CCND1
# K-ras N00014 EGFR* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> CCND1
# K-ras N00016 PDGF* -> PDGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00018 PDGFR* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00020 FGFR* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00022 EGF -> (ERBB2*+EGFR) -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00031 FLT3* -> GRB2 -> SOS -> RAS -> PI3K -> PIP3 -> AKT -| BAD
# K-ras N00032 (KRAS*,NRAS*) -> PI3K -> PIP3 -> AKT -| BAD
# K-ras N00041 EGFR* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00097 RAS // (RASSF1*+RASSF5) // STK4
# K-ras N00104 KRAS* -> RALGDS -> RAL
# K-ras N00230 TGFA* -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00235 IGF2* -> IGF1R -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00237 IGF2 -> IGF1R* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00246 HGF* -> MET -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00248 MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00252 EGF -> (ERBB2*+EGFR) -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00259 MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00276 EGF* -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00278 EREG* -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00280 AREG* -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00513 EGFR* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> CCND1
# K-ras N00876 FGF8* // FGFR1 -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00877 FGF17* // FGFR1 -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00878 FGF8 // FGFR1* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00913 IGF* // IGF1R -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00914 IGF // IGF1R* // GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N00996 APP* -> Abeta -> AGER -> RAS -> RAF -> MEK -> ERK -> NFKB => (TNF,IL6,NOS2)
# K-ras N01062 MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# K-ras N01064 RET* -> RAS -> RAF -> MEK -> ERK
# K-ras N10027 [Non-small cell lung cancer] Sotorasib -| KRAS*
# p53 N00067 CDKN2A* // MDM2 -| TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F
# p53 N00068 MDM2* -| TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F
# p53 N00076 CDKN2A* // MDM2 -| TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F
# p53 N00115 TP53* // (CDKN1A,GADD45,BAX,BAK1,DDB2,POLK)
# p53 N00131 MYCN* -- MAX => (MDM2,PTK2,TP53,BMI1)
# p53 N00982 HTT* -> TP53 => (BAX,BBC3)
# p53 N01058 DJ1* // TP53 => DUSP1
# c-Met N00005 MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> CCND1
# c-Met N00044 MET* -> GAB1 -> PI3K -> PIP3 -> AKT -| BAD
# c-Met N00143 ASPL-TFE3 => MET
# c-Met N00246 HGF* -> MET -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# c-Met N00247 HGF* -> MET -> GAB1 -> PI3K -> PIP3 -> AKT -| BAD
# c-Met N00248 MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# c-Met N00249 MET* -> GAB1 -> PI3K -> PIP3 -> AKT -| BAD
# c-Met N00259 MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# c-Met N00260 MET* -> GAB1 -> PI3K -> PIP3 -> AKT -> MTOR
# c-Met N01062 MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# c-Met N01063 MET* -> GAB1 -> PI3K -> PIP3 -> AKT -> MTOR
# c-Met N10024 (Capmatinib,Tepotinib) -| MET*
# ERBB2 N00022 EGF -> (ERBB2*+EGFR) -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# ERBB2 N00034 EGF -> (ERBB2*+EGFR) -> PI3K -> PIP3 -> AKT -> MTOR -> S6K
# ERBB2 N00087 (DLL,JAG) -> (NOTCH1*,NOTCH4*) => (ERBB2,HES1,HES5,HEY,FLT4)
# ERBB2 N00095 EGF -> (ERBB2*+EGFR) -> JAK1 -> STAT1/3 => VEGFA
# ERBB2 N00252 EGF -> (ERBB2*+EGFR) -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# ERBB2 N00253 EGF -> (ERBB2*+EGFR) -> PI3K -> PIP3 -> AKT -> MTOR -> S6K
# ERBB2 N10009 (Trastuzumab,Trastuzumab_emtansine,Pertuzumab,Lapatinib,Neratinib,Tucatinib,Margetuximab) -| (ERBB2*,ERBB2*)
# p16/INK4A N00067 CDKN2A* // MDM2 -| TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F
# p16/INK4A N00070 CDKN2A* // (CCND+CDK4/6) -> RB1 // E2F
# p16/INK4A N00071 CDKN2A* // (CCND+CDK4/6) -> RB1 // E2F
# p16/INK4A N00076 CDKN2A* // MDM2 -| TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F

# %% [markdown]
# From above, you will notice some interactions are not spelled out.  For example, 'RB1 // E2F' is not elucidated in the definition per KEGG's annotation.  Next I will make use of PubMed abstracts to see if the interaction(s) can be made clear.

# %%
p16 = []
for entry in interim:
    if 'p16/INK4A' == entry[0]:
        p16.append([entry[0], entry[2], entry[4], entry[5], entry[6]])

# %%
p16
# Out:
# [['p16/INK4A',
#   'N00066',
#   'CDKN2A -| MDM2 -| TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F',
#   '1029 -| 4193 -| 7157 => 1026 -| ((595,894,896)+(1019,1021)) -> 5925 // (1869,1870,1871)',
#   ['null']],
#  ['p16/INK4A',
#   'N00067',
#   'CDKN2A* // MDM2 -| TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F',
#   '1029v1 // 4193 -| 7157 => 1026 -| ((595,894,896)+(1019,1021)) -> 5925 // (1869,1870,1871)',
#   '1029v1 (CDKN2A*)  CDKN2A deletion'],
#  ['p16/INK4A',
#   'N00069',
#   'CDKN2A -| (CCND+CDK4/6) -> RB1 // E2F',
#   '1029 -| ((595,894,896)+(1019,1021)) -> 5925 // (1869,1870,1871)',
#   ['null']],
#  ['p16/INK4A',
#   'N00070',
#   'CDKN2A* // (CCND+CDK4/6) -> RB1 // E2F',
#   '1029v2 // ((595,894,896)+(1019,1021)) -> 5925 // (1869,1870,1871)',
#   '1029v2 (CDKN2A*)  CDKN2A mutation'],
#  ['p16/INK4A',
#   'N00071',
#   'CDKN2A* // (CCND+CDK4/6) -> RB1 // E2F',
#   '1029v1 // ((595,894,896)+(1019,1021)) -> 5925 // (1869,1870,1871)',
#   '1029v1 (CDKN2A*)  CDKN2A deletion'],
#  ['p16/INK4A',
#   'N00076',
#   'CDKN2A* // MDM2 -| TP53 => CDKN1A -| (CCND+CDK4/6) -> RB1 // E2F',
#   '1029v2 // 4193 -| 7157 => 1026 -| ((595,894,896)+(1019,1021)) -> 5925 // (1869,1870,1871)',
#   '1029v2 (CDKN2A*)  CDKN2A mutation'],
#  ['p16/INK4A', 'N00494', 'TAX -| CDKN2A', 'K21857 -| 1029', ['null']],
#  ['p16/INK4A',
#   'N00536',
#   'CDKN2A -| MDM2 -| TP53 => CDKN1A -| (CCNE+CDK2) -> RB1 // E2F',
#   '1029 -| 4193 -| 7157 => 1026 -| ((898,9134)+1017) -> 5925 // (1869,1870,1871)',
#   ['null']]]

# %%
df = pd.DataFrame(p16, columns=['pathway','networkId','definition','code','mutation'])

# %%
df.to_csv('p16.csv', index=False)
